# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('../Datasets/cleaned_data.csv')

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Status                2000 non-null   object
#  1   Age Group             2000 non-null   object
#  2   Education             2000 non-null   object
#  3   Industry              2000 non-null   object
#  4   Location              2000 non-null   object
#  5   AI Risk               2000 non-null   object
#  6   Years of Experience   2000 non-null   float64
#  7   Monthly Salary (INR)  2000 non-null   float64
#  8   Date Recorded         2000 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 140.8+ KB

# %%
df.describe()
# Out:
#        Years of Experience  Monthly Salary (INR)
# count           2000.00000           2000.000000
# mean              15.51725          76997.950000
# std                6.44485          37464.139276
# min                0.00000           5100.000000
# 25%               14.50000          49150.000000
# 50%               15.00000          78100.000000
# 75%               18.00000         104125.000000
# max               30.00000         149900.000000

# %%
df.head()
# Out:
#        Status Age Group    Education    Industry   Location AI Risk  \
# 0    Employed     25-34  High school  Technology      Urban    High
# 1    Employed     18-24      Diploma     Finance      Rural  Medium
# 2    Employed     25-34  High school      Retail      Delhi     Low
# 3  Unemployed     18-24     Master's      Retail      Urban     Low
# 4    Employed     45-54      Diploma     Finance  Hyderabad     Low
#
#    Years of Experience  Monthly Salary (INR) Date Recorded
# 0                 18.0               40700.0    2023-01-01
# 1                 15.0               17500.0    2023-01-02
# 2                 16.0               77600.0    2023-01-03
# 3                 30.0              100200.0    2023-01-04
# 4                  9.0               19500.0    2023-01-05

# %%
# Countplot

sns.set_theme(style="darkgrid")
sns.countplot(df,x='Status')
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
# Histplot 
sns.histplot(df,x='Monthly Salary (INR)',kde=True)
# Out:
# <Axes: xlabel='Monthly Salary (INR)', ylabel='Count'>

# %%
# Countplot
sns.countplot(df,x='Education', hue='AI Risk')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
# Boxplot
age_order = ['18-24', '25-34', '35-44', '45-54', '55+']
sns.boxplot(df,x='Age Group',y='Monthly Salary (INR)',order=age_order)
# Out:
# <Axes: xlabel='Age Group', ylabel='Monthly Salary (INR)'>

# %%
# Barplot
sns.barplot(df,x='Location',y='Monthly Salary (INR)',estimator=np.mean)
# Out:
# <Axes: xlabel='Location', ylabel='Monthly Salary (INR)'>

# %%
# Heatmap
sns.heatmap(df.select_dtypes('number').corr())
# Out:
# <Axes: >

# %%
# Scatterplot
sns.relplot(df, x='Years of Experience',y='Monthly Salary (INR)',hue='Industry',size='Monthly Salary (INR)',col='Location',kind='scatter',col_wrap=2)
